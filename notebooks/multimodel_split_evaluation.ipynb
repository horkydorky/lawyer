# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve().parent
sys.path.append(str(PROJECT_ROOT))
from config.paths import DATA_DIR, VECTORSTORE1_DIR, EVAL_PATH,VECTORSTORE_DIR,VECTORSTORE2_DIR

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
import json
from pathlib import Path
from typing import List, Dict

def load_corpus_with_recursive_splitter(json_dir: Path, chunk_size: int = 512, chunk_overlap: int = 100):
    """
    Load legal corpus from JSON files, preserving original article numbering
    and splitting text into semantically coherent chunks using
    RecursiveCharacterTextSplitter.
    """
    corpus = []
    pairs = []

    splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        separators=["\n\n", ".", "?", "!", ";", ":", " "],
    )

    for file in json_dir.glob("*.json"):
        with open(file, "r", encoding="utf-8") as f:
            data = json.load(f)

        if not isinstance(data, dict):
            print(f"⚠️ Unexpected format in {file.name}, skipping...")
            continue

        # Auto-detect title or fallback to filename
        file_title = data.get("document_title", file.stem.replace("_", " ").title())

        # --- Process preamble ---
        preamble = data.get("preamble", "")
        if preamble and preamble.strip():
            chunks = splitter.split_text(preamble)
            for i, chunk in enumerate(chunks, start=1):
                corpus.append({
                    "text": chunk.strip(),
                    "chapter": "Preamble",
                    "section": f"Preamble (chunk {i}/{len(chunks)})" if len(chunks) > 1 else "Preamble",
                    "source": file_title,
                    "section_type": "preamble",
                    "chunk_id": i,
                    "total_chunks": len(chunks),
                })
                pairs.append(f"[{file_title}] Preamble (chunk {i}/{len(chunks)})")

        # --- Process parts and articles ---
        for part in data.get("parts", []):
            if not isinstance(part, dict):
                continue
            part_num = part.get("part_number", "")
            part_title = part.get("part_title", "")
            chapter_name = f"Part {part_num}: {part_title}".strip()

            for article in part.get("articles", []):
                if not isinstance(article, dict):
                    continue

                art_num = article.get("article_number", "")
                art_title = article.get("article_title", "")
                clauses = article.get("clauses", [])

                combined_text = "\n\n".join([c.strip() for c in clauses if c and c.strip()])
                if not combined_text:
                    continue

                chunks = splitter.split_text(combined_text)
                for i, chunk in enumerate(chunks, start=1):
                    section_name = (
                        f"Article {art_num} (chunk {i}/{len(chunks)})"
                        if len(chunks) > 1 else f"Article {art_num}"
                    )
                    corpus.append({
                        "text": chunk.strip(),
                        "chapter": chapter_name,
                        "section": section_name,
                        "source": file_title,
                        "section_type": "article",
                        "part_number": part_num,
                        "article_number": art_num,
                        "article_title": art_title,
                        "num_clauses": len(clauses),
                        "chunk_id": i,
                        "total_chunks": len(chunks),
                    })
                    pairs.append(f"[{file_title}] {chapter_name} | {section_name}")

        # --- Process schedules ---
        for schedule in data.get("schedules", []):
            if not isinstance(schedule, dict):
                continue

            schedule_num = schedule.get("schedule_number", "")
            schedule_title = schedule.get("schedule_title", "")
            schedule_text = schedule.get("schedule_text", "")

            combined = (schedule_title + "\n\n" + schedule_text).strip()
            if not combined:
                continue

            chunks = splitter.split_text(combined)
            for i, chunk in enumerate(chunks, start=1):
                section_name = (
                    f"Schedule {schedule_num} (chunk {i}/{len(chunks)})"
                    if len(chunks) > 1 else f"Schedule {schedule_num}"
                )
                corpus.append({
                    "text": chunk.strip(),
                    "chapter": "Schedules",
                    "section": section_name,
                    "source": file_title,
                    "section_type": "schedule",
                    "schedule_number": schedule_num,
                    "chunk_id": i,
                    "total_chunks": len(chunks),
                })
                pairs.append(f"[{file_title}] Schedules | {section_name}")

    print(f"\n✅ Loaded {len(corpus)} text chunks (Recursive splitter, overlap={chunk_overlap}).")
    print("🧩 Example labels:")
    print("\n".join(pairs[:10]), "...")
    return corpus

# %%
json_dir = DATA_DIR / "processed"
print("\n" + "=" * 80)
print("Version 2: Original numbering from JSON (Article 45, 46...)")
print("=" * 80)
corpus2 = load_corpus_with_recursive_splitter(json_dir)
# Out:
# ================================================================================
# Version 2: Original numbering from JSON (Article 45, 46...)
# ================================================================================
#
# ✅ Loaded 5494 text chunks (Recursive splitter, overlap=100).
# 🧩 Example labels:
# [Bank and Financial Institution Act, 2073 (2017)] Preamble (chunk 1/2)
# [Bank and Financial Institution Act, 2073 (2017)] Preamble (chunk 2/2)
# [Bank and Financial Institution Act, 2073 (2017)] Part 1: Preliminary | Article 1
# [Bank and Financial Institution Act, 2073 (2017)] Part 1: Preliminary | Article 2 (chunk 1/41)
# [Bank and Financial Institution Act, 2073 (2017)] Part 1: Preliminary | Article 2 (chunk 2/41)
# [Bank and Financial Institution Act, 2073 (2017)] Part 1: Preliminary | Article 2 (chunk 3/41)
# [Bank and Financial Institution Act, 2073 (2017)] Part 1: Preliminary | Article 2 (chunk 4/41)
# [Bank and Financial Institution Act, 2073 (2017)] Part 1: Preliminary | Article 2 (chunk 5/41)
# [Bank and Financial Institution Act, 2073 (2017)] Part 1: Preliminary | Article 2 (chunk 6/41)
# [Bank and Financial Institution Act, 2073 (2017)] Part 1: Preliminary | Article 2 (chunk 7/41) ...

# %%
import numpy as np
from typing import List, Dict
from sklearn.feature_extraction.text import TfidfVectorizer
from rank_bm25 import BM25Okapi


class TFIDFRetriever:
    def __init__(self, docs_with_meta: List[Dict]):
        # Store both text and metadata
        self.docs = docs_with_meta
        texts = [d["text"] for d in docs_with_meta]
        self.vectorizer = TfidfVectorizer(stop_words="english")
        self.doc_vectors = self.vectorizer.fit_transform(texts)

    def retrieve(self, query: str, top_k: int = 5) -> List[Dict]:
        q_vec = self.vectorizer.transform([query])
        scores = np.dot(q_vec, self.doc_vectors.T).toarray()[0]
        top_idx = np.argsort(scores)[::-1][:top_k]
        return [self.docs[i] for i in top_idx]


class BM25Retriever:
    def __init__(self, docs_with_meta: List[Dict]):
        self.docs = docs_with_meta
        self.tokenized = [d["text"].lower().split() for d in docs_with_meta]
        self.bm25 = BM25Okapi(self.tokenized)

    def retrieve(self, query: str, top_k: int = 5) -> List[Dict]:
        tokens = query.lower().split()
        scores = self.bm25.get_scores(tokens)
        top_idx = np.argsort(scores)[::-1][:top_k]
        return [self.docs[i] for i in top_idx]

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma
from pathlib import Path
from typing import List, Dict


def load_chroma_retriever(model_name: str, subdir: str, k: int = 5):
    """Load Chroma retriever for a given model store with chapter name only."""
    embedder = HuggingFaceEmbeddings(model_name=model_name)
    db_path = VECTORSTORE2_DIR / subdir
    if not db_path.exists():
        raise FileNotFoundError(f"❌ Vectorstore not found at {db_path}")
    
    db = Chroma(persist_directory=str(db_path), embedding_function=embedder)
    retriever = db.as_retriever(search_type="similarity", search_kwargs={"k": k})

    def get_chapter_name(meta: Dict) -> str:
        """Extract chapter name (title only, no numbers) from metadata."""
        # Try to get the full chapter string first
        chapter = meta.get("chapter", "")
        
        # If chapter exists and has a colon, extract the part after it
        if chapter and isinstance(chapter, str) and ":" in chapter:
            # e.g., "Part 2: Fundamental Rights" -> "Fundamental Rights"
            return chapter.split(":", 1)[1].strip()
        elif chapter and isinstance(chapter, str):
            # If no colon, check if it starts with "Part" or "Chapter"
            if chapter.lower().startswith(("part ", "chapter ")):
                # Try to extract just the title if format is "Part X Title"
                parts = chapter.split(maxsplit=2)
                if len(parts) > 2:
                    return parts[2]
            return chapter
        
        # Fallback: get part_title directly
        part_title = meta.get("part_title", "")
        if part_title:
            return part_title
        
        # Last resort fallback
        return "Unknown Chapter"

    class ChromaRetrieverWithMeta:
        """Wrapper retriever returning text and chapter name only."""
        def __init__(self, retriever):
            self.retriever = retriever

        def retrieve(self, query: str, top_k: int = 5) -> List[Dict]:
            docs = self.retriever.invoke(query)
            results = []
            for doc in docs:
                chapter_name = get_chapter_name(doc.metadata)
                source = (
                    doc.metadata.get("source")
                    or doc.metadata.get("file_name")
                    or doc.metadata.get("document_id")
                    or "Unknown Source"
                )
                results.append({
                    "text": doc.page_content,
                    "metadata": chapter_name,
                    "source": source
                })
            return results

    return ChromaRetrieverWithMeta(retriever), db

# %%
from typing import List, Dict
import numpy as np
from langchain_core.documents import Document

class CascadedHybridRetriever:
    """
    Hybrid retriever where a semantic retriever gets top_n_sem documents,
    then a keyword-based retriever (e.g., BM25) reranks those for top_k final results.
    Returns only chapter name in metadata.
    """
    def __init__(self, keyword_retriever, semantic_retriever):
        self.keyword_retriever = keyword_retriever
        self.semantic_retriever = semantic_retriever

    def retrieve(self, query: str, top_k: int = 5, top_n_sem: int = 15) -> List[Dict]:
        # --- Step 1: Use semantic retriever first ---
        if hasattr(self.semantic_retriever, "retrieve"):
            sem_docs = self.semantic_retriever.retrieve(query, top_k=top_n_sem)
        elif hasattr(self.semantic_retriever, "invoke"):
            sem_docs = self.semantic_retriever.invoke(query)
        elif hasattr(self.semantic_retriever, "get_relevant_documents"):
            sem_docs = self.semantic_retriever.get_relevant_documents(query)
        else:
            raise AttributeError(
                "Semantic retriever must have invoke(), get_relevant_documents(), or retrieve()."
            )

        # --- Step 2: Normalize semantic outputs ---
        mini_corpus = []
        for d in sem_docs:
            if isinstance(d, dict):
                text = d.get("text", "")
                meta = d.get("metadata", {})
            else:  # LangChain Document
                text = getattr(d, "page_content", "")
                meta = getattr(d, "metadata", {})
            mini_corpus.append({"text": text, "metadata": meta})

        # --- Step 3: Rerank using keyword retriever (BM25) ---
        keyword_refiner = self.keyword_retriever.__class__(mini_corpus)
        refined_docs = keyword_refiner.retrieve(query, top_k=top_k)

        # --- Step 4: Format results with chapter name only ---
        results = []
        for d in refined_docs:
            meta = d.get("metadata", {})
            
            # Get chapter name (title only, no numbers)
            if isinstance(meta, str):
                # If it's already a string, try to extract title
                if ":" in meta:
                    chapter_name = meta.split(":", 1)[1].strip()
                else:
                    chapter_name = meta
            elif isinstance(meta, dict):
                chapter = meta.get("chapter", "")
                
                # Extract title from "Part X: Title" format
                if chapter and ":" in chapter:
                    chapter_name = chapter.split(":", 1)[1].strip()
                elif chapter:
                    chapter_name = chapter
                else:
                    # Fallback to part_title directly
                    chapter_name = meta.get("part_title", "Unknown Chapter")
            else:
                chapter_name = "Unknown Chapter"
            
            # Get source
            if isinstance(meta, dict):
                source = (
                    meta.get("source") 
                    or meta.get("document_title") 
                    or "Unknown Source"
                )
            else:
                source = "Unknown Source"

            results.append({
                "text": d["text"],
                "metadata": chapter_name,
                "source": source
            })

        return results

# %%
model_stores = {
        "BAAI/bge-base-en-v1.5": "bge_base_store",
        "BAAI/bge-large-en-v1.5": "bge_large_store",
        "sentence-transformers/all-MiniLM-L6-v2": "minilm_store",
    }

# %%
json_dir = DATA_DIR / "processed"
corpus_with_meta = load_corpus_with_recursive_splitter(json_dir)  # returns list of dicts with 'text', 'chapter', 'section'

# # Optionally add a 'source' field for each doc
all_docs = []
for doc in corpus_with_meta:
    all_docs.append({
        "text": doc["text"],
        "chapter": doc["chapter"],
        "section": doc["section"],
        "source": doc.get("source")  
})
# Out:
# ✅ Loaded 5494 text chunks (Recursive splitter, overlap=100).
# 🧩 Example labels:
# [Bank and Financial Institution Act, 2073 (2017)] Preamble (chunk 1/2)
# [Bank and Financial Institution Act, 2073 (2017)] Preamble (chunk 2/2)
# [Bank and Financial Institution Act, 2073 (2017)] Part 1: Preliminary | Article 1
# [Bank and Financial Institution Act, 2073 (2017)] Part 1: Preliminary | Article 2 (chunk 1/41)
# [Bank and Financial Institution Act, 2073 (2017)] Part 1: Preliminary | Article 2 (chunk 2/41)
# [Bank and Financial Institution Act, 2073 (2017)] Part 1: Preliminary | Article 2 (chunk 3/41)
# [Bank and Financial Institution Act, 2073 (2017)] Part 1: Preliminary | Article 2 (chunk 4/41)
# [Bank and Financial Institution Act, 2073 (2017)] Part 1: Preliminary | Article 2 (chunk 5/41)
# [Bank and Financial Institution Act, 2073 (2017)] Part 1: Preliminary | Article 2 (chunk 6/41)
# [Bank and Financial Institution Act, 2073 (2017)] Part 1: Preliminary | Article 2 (chunk 7/41) ...

# %%
tfidf_model = TFIDFRetriever(all_docs)
bm25_model = BM25Retriever(all_docs)
def inspect_all_models(query: str, top_k: int = 5):
    print("\n" + "="*120)
    print(f" Retrieval Inspection for Query:\n {query}")
    print("="*120)
    
    # --- Keyword / TF-IDF / BM25 ---
    print("\n[TF-IDF]\n")
    result_tfidf = tfidf_model.retrieve(query, top_k=top_k)
    for r in result_tfidf:
        chapter = r.get('chapter', 'Unknown Chapter')
        # Extract title only (after colon if present)
        if ':' in chapter:
            chapter_name = chapter.split(':', 1)[1].strip()
        else:
            chapter_name = chapter
        print(f"{chapter_name}")
    
    print("\n[BM25]\n")
    result_bm25 = bm25_model.retrieve(query, top_k=top_k)
    for r in result_bm25:
        chapter = r.get('chapter', 'Unknown Chapter')
        # Extract title only (after colon if present)
        if ':' in chapter:
            chapter_name = chapter.split(':', 1)[1].strip()
        else:
            chapter_name = chapter
        print(f"{chapter_name}")
    
    # ------- Hybrid --------
    print("\n[Hybrid_Retriever]\n")
    bert, db_hybrid = load_chroma_retriever("BAAI/bge-large-en-v1.5", "bge_large_store")
    hybrid = CascadedHybridRetriever(bm25_model, bert)
    results_hybrid = hybrid.retrieve(query, top_k=top_k, top_n_sem=20)
    for i, r in enumerate(results_hybrid, 1):
        print(f"{r['metadata']}")
        
    # --- Semantic Vector Models ---
    for model_name, subdir in model_stores.items():
        print(f"\n[{model_name}]\n")
        semantic_retriever, db = load_chroma_retriever(model_name, subdir,k=top_k)
        results = semantic_retriever.retrieve(query, top_k=top_k)
        for r in results:
            print(r["metadata"])
        
    print("\n" + "="*120)

# %%
# ============================================================
# 🔹 Gemini Chroma Retriever (Title-Only Version)
# ============================================================

import os
from pathlib import Path
from dotenv import load_dotenv
import chromadb
from chromadb.config import Settings
from google import genai


class GeminiChromaRetriever:
    def __init__(self, collection_name="legal_docs", db_path=None):
        self.collection_name = collection_name
        self.db_path = db_path or (Path.cwd() / "chroma_db")

        load_dotenv()
        API_KEY = os.getenv("GEMINI_API_KEY")
        if not API_KEY:
            raise ValueError("❌ Missing GEMINI_API_KEY in .env")

        self.client = genai.Client(api_key=API_KEY)
        self.client_chroma = chromadb.PersistentClient(path=str(self.db_path))

        try:
            self.collection = self.client_chroma.get_collection(name=self.collection_name)
        except Exception:
            raise ValueError(f"❌ Collection '{self.collection_name}' not found at {self.db_path}")

    def get_query_embedding(self, text):
        """Generate embedding for the query."""
        response = self.client.models.embed_content(
            model="models/text-embedding-004",
            contents=[text]
        )
        return response.embeddings[0].values

    def retrieve(self, query, top_k=5):
        """
        Retrieve top-k documents but only return metadata title.
        Returns list of dicts like:
        [{"metadata": "Chapter 2|Section 3"}, ...]
        """
        query_emb = self.get_query_embedding(query)
        results = self.collection.query(query_embeddings=[query_emb], n_results=top_k)

        retrieved = []
        for doc, meta, score in zip(
            results["documents"][0],
            results["metadatas"][0],
            results["distances"][0]
        ):
            # ✅ Extract the part_title if present, else fallback to chapter|section
            if isinstance(meta, dict):
                meta_str = meta.get("part_title") or f"{meta.get('chapter', '')}|{meta.get('section', '')}"
            else:
                meta_str = str(meta)

            retrieved.append({
                "metadata": meta_str.strip()
            })

        return retrieved

# %%
import json
import numpy as np
from typing import List, Dict
from pathlib import Path
import re

# ============================================================
# 🔹 Metric Functions
# ============================================================
import numpy as np
from typing import List

def precision_at_k(retrieved: List[str], relevant: List[str]) -> float:
    if not retrieved:
        return 0.0
    relevant_hits = sum(1 for r in retrieved if r in relevant)
    return relevant_hits / len(retrieved)


def recall_at_k(retrieved: List[str], relevant: List[str]) -> float:
    if not relevant:
        return 0.0
    relevant_hits = sum(1 for r in retrieved if r in relevant)
    recall = relevant_hits / len(relevant)
    return min(recall, 1.0)  # ✅ Cap recall to 1.0


def hit_rate(retrieved: List[str], relevant: List[str]) -> float:
    return 1.0 if any(r in relevant for r in retrieved) else 0.0


def mrr_at_k(retrieved: List[str], relevant: List[str]) -> float:
    for i, r in enumerate(retrieved, start=1):
        if r in relevant:
            return 1.0 / i
    return 0.0

def ndcg_at_k(retrieved: List[str], relevant: List[str]) -> float:
    if not relevant:
        return 0.0

    # Keep track of which relevant items have been counted
    counted = set()
    dcg = 0.0

    for i, r in enumerate(retrieved[:len(retrieved)]):
        if r in relevant and r not in counted:
            dcg += 1 / np.log2(i + 2)  # rank i+1
            counted.add(r)
            if len(counted) == len(relevant):
                break  # all relevant counted

    # Ideal DCG: all relevant first
    ideal_dcg = sum(1 / np.log2(i + 2) for i in range(len(relevant)))

    return dcg / ideal_dcg if ideal_dcg > 0 else 0.0



# ============================================================
# 🔹 Helper: Extract Chapter (Lowercased)
# ============================================================
def extract_chapter1(meta_str: str) -> str:
    if not meta_str or not isinstance(meta_str, str):
        return "unknown"

    parts = meta_str.split("|")
    chapter = parts[0].strip().lower()

    chapter = re.sub(r"^(?:part\s*[-\w]*\s*:?\s*)+", "", chapter, flags=re.IGNORECASE)
    chapter = re.sub(r"^(?:chapter\s*[-\w]*\s*:?\s*)+", "", chapter, flags=re.IGNORECASE)

    chapter = re.sub(r"^[-]?\d+\s*:\s*", "", chapter)

    chapter = re.sub(r"^\s*:\s*", "", chapter).strip()

    return chapter if chapter else "unknown"



# ============================================================
# 🔹 Benchmarking Function
# ============================================================
def evaluate_retriever1(eval_path: Path, retriever, all_docs: List[Dict], top_k: int = 5):
    """
    Evaluate retriever using queries and relevant chapters from eval dataset.
    Supports both nested and top-level chapter metadata.
    """
    with open(eval_path, "r", encoding="utf-8") as f:
        eval_data = json.load(f)

    metrics = {"precision": [], "recall": [], "hit_rate": [], "mrr": [], "ndcg": []}

    for i, item in enumerate(eval_data, 1):
        query = item.get("query", "")

        # 🟢 Ensure relevant_meta is list
        relevant_meta = item.get("relevant_meta", [])
        if isinstance(relevant_meta, str):
            relevant_meta = [relevant_meta]
        relevant_chapters = [extract_chapter1(m) for m in relevant_meta]

        # --- Retrieve results ---
        top_docs = retriever.retrieve(query, top_k=top_k)
        retrieved_chapters = []

        for d in top_docs:
            # Handle both metadata structures
            if "metadata" in d and isinstance(d["metadata"], dict):
                meta_str = f"{d['metadata'].get('chapter', '')}|{d['metadata'].get('section', '')}"
                retrieved_chapters.append(extract_chapter1(meta_str))
            elif "chapter" in d:
                retrieved_chapters.append(extract_chapter1(d["chapter"]))
            else:
                retrieved_chapters.append("unknown")

        # --- Compute metrics ---
        p = precision_at_k(retrieved_chapters, relevant_chapters)
        r = recall_at_k(retrieved_chapters, relevant_chapters)
        h = hit_rate(retrieved_chapters, relevant_chapters)
        m = mrr_at_k(retrieved_chapters, relevant_chapters)
        n = ndcg_at_k(retrieved_chapters, relevant_chapters)

        metrics["precision"].append(p)
        metrics["recall"].append(r)
        metrics["hit_rate"].append(h)
        metrics["mrr"].append(m)
        metrics["ndcg"].append(n)

        # --- Print result ---
        print(f"\n{i}. {query}")
        print(f"   Relevant: {relevant_chapters}")
        print(f"   Retrieved: {retrieved_chapters[:top_k]}")
        print(f"   → Precision={p:.2f}, Recall={r:.2f}, Hit={h:.1f}, MRR={m:.2f}, NDCG={n:.2f}")

    # --- Summary ---
    summary = {k: float(np.mean(v)) for k, v in metrics.items()}
    print("\n✅ Evaluation Summary (Average):")
    print(json.dumps(summary, indent=2))
    return summary

# %%
import json
import numpy as np
from typing import List, Dict
from pathlib import Path

# ============================================================
# 🔹 Helper: Extract Chapter (Lowercased)
# ============================================================
def extract_chapter(meta_str: str) -> str:
    """
    Extract only the 'chapter x' portion from metadata like 'Chapter 3|Section 5',
    normalized to lowercase for comparison consistency.
    """
    if not meta_str or not isinstance(meta_str, str):
        return "unknown"
    parts = meta_str.split("|")
    chapter = parts[0].strip().lower()
    if not chapter.startswith("chapter"):
        chapter = f"{chapter}"
    return chapter


# ============================================================
# 🔹 Benchmarking Function
# ============================================================
def evaluate_retriever(eval_path: Path, retriever, top_k: int = 5):
    """
    Evaluate retriever using queries and relevant chapters from eval dataset.
    Retrieved chapters are simplified to only the chapter name (lowercase).
    """
    with open(eval_path, "r", encoding="utf-8") as f:
        eval_data = json.load(f)

    metrics = {"precision": [], "recall": [], "hit_rate": [], "mrr": [], "ndcg": []}

    for i, item in enumerate(eval_data, 1):
        query = item.get("query", "")

        # 🟢 Ensure relevant_meta is list
        relevant_meta = item.get("relevant_meta", [])
        if isinstance(relevant_meta, str):
            relevant_meta = [relevant_meta]

        relevant_chapters = [extract_chapter(m) for m in relevant_meta]

        # --- Retrieve results ---
        top_docs = retriever.retrieve(query, top_k=top_k)
        retrieved_chapters = []
        for d in top_docs:
            if isinstance(d, dict):
                meta = d.get("metadata", "")
                if isinstance(meta, str):
                    retrieved_chapters.append(extract_chapter(meta))
                elif isinstance(meta, dict):
                    # If metadata is a dict, combine chapter and section keys safely
                    meta_str = f"{meta.get('chapter','')}|{meta.get('section','')}"
                    retrieved_chapters.append(extract_chapter(meta_str))
                else:
                    retrieved_chapters.append("unknown")
            else:
                retrieved_chapters.append("unknown")

        # --- Compute metrics ---
        p = precision_at_k(retrieved_chapters, relevant_chapters)
        r = recall_at_k(retrieved_chapters, relevant_chapters)
        h = hit_rate(retrieved_chapters, relevant_chapters)
        m = mrr_at_k(retrieved_chapters, relevant_chapters)
        n = ndcg_at_k(retrieved_chapters, relevant_chapters)

        metrics["precision"].append(p)
        metrics["recall"].append(r)
        metrics["hit_rate"].append(h)
        metrics["mrr"].append(m)
        metrics["ndcg"].append(n)

        # --- Print result ---
        print(f"\n{i}. {query}")
        print(f"   Relevant: {relevant_chapters}")
        print(f"   Retrieved: {retrieved_chapters[:top_k]}")
        print(f"   → Precision={p:.2f}, Recall={r:.2f}, Hit={h:.1f}, MRR={m:.2f}, NDCG={n:.2f}")

    # --- Summary ---
    summary = {k: float(np.mean(v)) for k, v in metrics.items()}
    print("\n✅ Evaluation Summary (Average):")
    print(json.dumps(summary, indent=2))
    return summary



# Example use:
# evaluate_retriever(EVAL_PATH, retriever, all_docs, top_k=5)

# %%
EVAL_FILE = EVAL_PATH
results = {}

results["TF-IDF"] = evaluate_retriever1(EVAL_FILE, tfidf_model, all_docs, top_k=5)
print("\n===================================================================\n")
results["BM25"] = evaluate_retriever1(EVAL_FILE, bm25_model, all_docs, top_k=5)
print("\n===================================================================\n")

bert, db_hybrid = load_chroma_retriever("BAAI/bge-large-en-v1.5", "bge_large_store")
hybrid = CascadedHybridRetriever(bm25_model, bert)
results["BGE Large + BM25 (Hybrid)"] = evaluate_retriever(EVAL_FILE, hybrid, top_k=5)
print("\n===================================================================\n")

for model_name, subdir in model_stores.items():
    semantic_retriever, db = load_chroma_retriever(model_name, subdir)
    results[model_name] = evaluate_retriever(EVAL_FILE, semantic_retriever, top_k=5)
    print("\n===================================================================\n")


gemini_retriever = GeminiChromaRetriever(
    collection_name="legal_docs",
    db_path=VECTORSTORE_DIR
)

results["text-embedding-004"] = evaluate_retriever(
    EVAL_FILE,
    gemini_retriever,
    top_k=5
)
print("\n===================================================================\n")
# Out:
# 1. What are the grounds for disqualification of members of Parliament under the Constitution?
#    Relevant: ['federal legislature', 'judiciary']
#    Retrieved: ['judiciary', 'transitional provisions', 'transitional provisions', 'general provisions', 'transitional provisions']
#    → Precision=0.20, Recall=0.50, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 2. Explain the constitutional provisions regarding the right to equality and non-discrimination. What are the permitted classifications?
#    Relevant: ['fundamental rights and duties', 'preliminary']
#    Retrieved: ['basic provisions relating to labours', 'fundamental rights and duties', 'provisions concerning transactions of securities', 'provisions relating to inter-country adoption', 'fundamental rights and duties']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.39
#
# 3. Describe the procedure for declaring a state of emergency under the Constitution of Nepal.
#    Relevant: ['emergency power', 'provisions relating to national security']
#    Retrieved: ['emergency power', 'provisions on capital, capital fund and liquid assets', 'state legislature', 'emergency power', 'emergency power']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 4. What constitutional remedies are available for the enforcement of fundamental rights in Nepal?
#    Relevant: ['amendment to the constitution', 'judiciary']
#    Retrieved: ['fundamental rights and duties', 'judiciary', 'judiciary', 'emergency power', 'national human rights commission']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.39
#
# 5. What provisions exist to safeguard minorities and marginalized groups in the Constitution of Nepal?
#    Relevant: ['fundamental rights and duties', 'preliminary']
#    Retrieved: ['definitions and interpretations', 'definitions and interpretations', 'fundamental rights and duties', 'provisions relating to occupation safety and health', 'fundamental rights and duties']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=0.33, NDCG=0.31
#
# 6. Explain the principle of separation of powers under the Constitution of Nepal.
#    Relevant: ['structure of state and distribution of state power', 'judiciary']
#    Retrieved: ['structure of state and distribution of state power', 'structure of state and distribution of state power', 'laws relating to property', 'preliminary', 'state executive']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 7. Discuss the composition and jurisdiction of constitutional councils and commissions in Nepal.
#    Relevant: ['miscellaneous', 'transitional provisions']
#    Retrieved: ['other commissions', 'interrelations between federation, state and local level', 'law relating to persons', 'miscellaneous', 'provisions relating to mortgage']
#    → Precision=0.20, Recall=0.50, Hit=1.0, MRR=0.25, NDCG=0.26
#
# 8. Explain the financial powers of Parliament and the procedure for budget formulation in Nepal.
#    Relevant: ['financial provisions', 'structure of state and distribution of state power']
#    Retrieved: ['public service commission', 'structure of state and distribution of state power', 'structure of state and distribution of state power', 'general provisions', 'provisions on board of directors and chief executive']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.39
#
# 9. Describe the federal structure and distribution of powers between the federation and provinces.
#    Relevant: ['structure of state and distribution of state power']
#    Retrieved: ['schedules', 'special provisions for entities', 'structure of state and distribution of state power', 'definitions and interpretations', 'structure of state and distribution of state power']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=0.33, NDCG=0.50
#
# 10. Explain the constitutional right to privacy guaranteed under the Constitution of Nepal.
#    Relevant: ['fundamental rights and duties', 'preliminary']
#    Retrieved: ['transitional provisions', 'preliminary', 'preliminary', 'preliminary', 'miscellaneous']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.39
#
# 11. Define the offence of cheating under the Muluki Penal Code.
#    Relevant: ['offences relating to cheating, criminal breach of trust and extortion']
#    Retrieved: ['general principles of sentencing', 'offences relating to cheating, criminal breach of trust and extortion', 'preliminary', 'general provisions', 'miscellaneous']
#    → Precision=0.20, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.63
#
# 12. Distinguish between private defense of body and property under the Penal Code.
#    Relevant: ['general provisions']
#    Retrieved: ['general principles of sentencing', 'general provisions', 'general provisions', 'provisions relating to succession', 'preliminary']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.63
#
# 13. Explain the degrees and principles of punishment under the Penal Code.
#    Relevant: ['general principles of sentencing']
#    Retrieved: ['general principles of sentencing', 'preliminary', 'general provisions', 'directive principles, policies and obligations of the state', 'general provisions']
#    → Precision=0.20, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 14. Discuss the concept of abetment and its punishment under the Penal Code.
#    Relevant: ['general provisions']
#    Retrieved: ['general principles of sentencing', 'general provisions', 'preliminary', 'general provisions', 'provisions relating to labour court']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.63
#
# 15. Differentiate between criminal breach of trust and theft under the Penal Code.
#    Relevant: ['offences relating to cheating, criminal breach of trust and extortion', 'provisions relating to trusts']
#    Retrieved: ['general principles of sentencing', 'offences relating to cheating, criminal breach of trust and extortion', 'provisions relating to trusts', 'offences relating to cheating, criminal breach of trust and extortion', 'provisions relating to trusts']
#    → Precision=0.80, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.69
#
# 16. Explain the offences of wrongful confinement and kidnapping under the Penal Code.
#    Relevant: ['offences relating to kidnapping or taking of hostages']
#    Retrieved: ['general principles of sentencing', 'preliminary', 'general provisions', 'preamble', 'offences relating to criminal trespass and criminal mischief']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 17. Discuss offences against public tranquility under the Penal Code.
#    Relevant: ['offences against public tranquility', 'offences against public interest, health, safety, convenience and morals', "'criminal offences'"]
#    Retrieved: ['general principles of sentencing', 'preamble', 'preliminary', 'general provisions', 'miscellaneous']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 18. Define ‘voluntarily causing hurt’ and ‘grievous hurt’ under the Penal Code.
#    Relevant: ['offences relating to hurt or grievous hurt', 'offence relating to medical treatment']
#    Retrieved: ['offences relating to hurt or grievous hurt', 'general principles of sentencing', 'general provisions', 'general provisions', 'offences relating to hurt or grievous hurt']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 19. Explain the offence of defamation and its defenses under the Penal Code.
#    Relevant: ['offence relating to defamation', 'fundamental rights and duties']
#    Retrieved: ['general principles of sentencing', 'fundamental rights and duties', 'preliminary', 'general provisions', 'offence relating to defamation']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.62
#
# 20. Discuss the offences of forgery and counterfeiting under the Penal Code.
#    Relevant: ['offences relating to documents', 'offences relating to currency']
#    Retrieved: ['general principles of sentencing', 'preliminary', 'general provisions', 'preamble', 'offences relating to documents']
#    → Precision=0.20, Recall=0.50, Hit=1.0, MRR=0.20, NDCG=0.24
#
# 21. Explain the doctrine of transferred malice under the Penal Code.
#    Relevant: ['preliminary', 'general principles of sentencing']
#    Retrieved: ['general principles of sentencing', 'preliminary', 'general provisions', 'provisions relating to succession', 'miscellaneous']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 22. Discuss the provisions relating to sexual offences and punishment under the Penal Code.
#    Relevant: ['sexual offences']
#    Retrieved: ['general principles of sentencing', 'provisions relating to occupation safety and health', 'preamble', 'provisions relating to occupation safety and health', 'preliminary']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 23. Explain the provisions for minimum wage under the Labour Act.
#    Relevant: ['basic provisions relating to labours', 'miscellaneous']
#    Retrieved: ['provisions relating to council and committee', 'criminal offences', 'criminal offences', 'miscellaneous', 'provisions relating to council and committee']
#    → Precision=0.20, Recall=0.50, Hit=1.0, MRR=0.25, NDCG=0.26
#
# 24. Describe the rules regarding maternity leave and benefits under the Labour Act.
#    Relevant: ['provisions relating to leave']
#    Retrieved: ['provisions relating to leave', 'provisions relating to leave', 'provisions relating to leave', 'preliminary', 'provisions relating to leave']
#    → Precision=0.80, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 25. What constitutes unfair labour practice under the Labour Act?
#    Relevant: ['provisions relating to fair labour practice', 'basic provisions relating to labours']
#    Retrieved: ['provisions relating to fair labour practice', 'provisions relating to fair labour practice', 'provisions relating to fair labour practice', 'provisions relating to complaint, punishment and appeal', 'provisions relating to occupation safety and health']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 26. Explain the legal provisions relating to child labour under the Labour Act.
#    Relevant: ['basic provisions relating to labours', 'fundamental rights and duties']
#    Retrieved: ['provisions relating to employment', 'provisions relating to occupation safety and health', 'directive principles, policies and obligations of the state', 'provisions relating to termination of employment', 'provisions relating to occupation safety and health']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 27. Describe the procedure for registration of trade unions under the Labour Act.
#    Relevant: ['basic provisions relating to labours', 'preliminary']
#    Retrieved: ['provisions relating to council and committee', 'basic provisions relating to labours', 'miscellaneous', 'provisions relating to council and committee', 'provisions relating to occupation safety and health']
#    → Precision=0.20, Recall=0.50, Hit=1.0, MRR=0.50, NDCG=0.39
#
# 28. Explain the process and importance of collective bargaining under the Labour Act.
#    Relevant: ['settlement of collective disputes', 'preliminary']
#    Retrieved: ['settlement of collective disputes', 'preliminary', 'settlement of collective disputes', 'settlement of collective disputes', 'settlement of collective disputes']
#    → Precision=1.00, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 29. Discuss the grounds and procedures for termination of employment under the Labour Act.
#    Relevant: ['provisions relating to termination of employment']
#    Retrieved: ['miscellaneous', 'provisions relating to termination of employment', 'provisions relating to employment', 'directive principles, policies and obligations of the state', 'provisions relating to termination of employment']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.63
#
# 30. Explain the provisions regarding social security and welfare funds under the Labour Act.
#    Relevant: ['provisions relating to provident fund, gratuity and insurance', "'provisions relating to remuneration'"]
#    Retrieved: ['miscellaneous', 'provisions relating to provident fund, gratuity and insurance', 'preliminary', 'provisions relating to termination of employment', 'provisions relating to provident fund, gratuity and insurance']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.39
#
# 31. Describe the provisions regarding provident fund and gratuity under the Labour Act.
#    Relevant: ['provisions relating to provident fund, gratuity and insurance']
#    Retrieved: ['provisions relating to provident fund, gratuity and insurance', 'provisions relating to part-time labours', 'provisions relating to provident fund, gratuity and insurance', 'provisions relating to complaint, punishment and appeal', 'provisions relating to provident fund, gratuity and insurance']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 32. Explain the process for settlement of individual labour disputes under the Labour Act.
#    Relevant: ['settlement of individual disputes']
#    Retrieved: ['interrelations between federation, state and local level', 'provisions relating to occupation safety and health', 'basic provisions relating to labours', 'settlement of individual disputes', 'provisions relating to supply of labours']
#    → Precision=0.20, Recall=1.00, Hit=1.0, MRR=0.25, NDCG=0.43
#
# 33. Discuss the legal framework governing strikes and lockouts under the Labour Act.
#    Relevant: ['settlement of collective disputes']
#    Retrieved: ['law relating to persons', 'law relating to persons', 'provisions relating to internal management of enterprise', 'provisions relating to occupation safety and health', 'law relating to persons']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 34. Explain the role and powers of Labour Courts under the Labour Act.
#    Relevant: ['provisions relating to labour court', 'preliminary']
#    Retrieved: ['provisions relating to occupation safety and health', 'basic provisions relating to labours', 'provisions relating to labour court', 'provisions relating to supply of labours', 'provisions relating to supply of labours']
#    → Precision=0.20, Recall=0.50, Hit=1.0, MRR=0.33, NDCG=0.31
#
# 35. Define a contract under the Muluki Civil Code and explain its essential elements.
#    Relevant: ['provisions relating to government, public and community properties']
#    Retrieved: ['general principles of sentencing', 'tax accounting and time', 'family law', 'public service commission', 'provisions relating to contracts of lease']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 36. Explain the rules relating to offer and acceptance under the Civil Code.
#    Relevant: ['provisions relating to government, public and community properties', 'provisions relating to trusts']
#    Retrieved: ['provisions relating to government, public and community properties', 'provisions relating to government, public and community properties', 'provisions relating to government, public and community properties', 'provisions relating to government, public and community properties', 'provisions relating to government, public and community properties']
#    → Precision=1.00, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 37. Discuss the various modes by which a contract may be discharged under the Civil Code.
#    Relevant: ['provisions relating to government, public and community properties', 'provisions relating to performance of contracts']
#    Retrieved: ['general principles of sentencing', 'public service commission', 'provisions relating to usufruct', 'provisions relating to contracts of lease', 'preliminary']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 38. Explain the remedies available for breach of contract under the Civil Code.
#    Relevant: ['provisions relating to government, public and community properties']
#    Retrieved: ['provisions relating to government, public and community properties', 'provisions relating to government, public and community properties', 'general principles of sentencing', 'provisions relating to government, public and community properties', 'public service commission']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 39. Discuss the legal effect of fraud, misrepresentation, and undue influence in contracts.
#    Relevant: ['provisions relating to contracts and other liabilities', 'family law']
#    Retrieved: ['family law', 'family law', 'preliminary', 'general provisions', 'family law']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 40. Explain the legal provisions regarding sale of goods under the Civil Code.
#    Relevant: ['provisions relating to trusts']
#    Retrieved: ['general principles of sentencing', 'preliminary', 'public service commission', 'preliminary', 'law relating to persons']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 41. Discuss the rights and duties of bailor and bailee under the Civil Code.
#    Relevant: ['provisions relating to contracts of bailment']
#    Retrieved: ['provisions relating to contracts of bailment', 'provisions relating to contracts of bailment', 'provisions relating to contracts of bailment', 'provisions relating to contracts of bailment', 'provisions relating to contracts of bailment']
#    → Precision=1.00, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 42. Explain the legal provisions relating to mortgage of immovable property.
#    Relevant: ['provisions relating to mortgage of immovable property', 'provisions relating to mortgage']
#    Retrieved: ['laws relating to property', 'provisions relating to mortgage', 'provisions relating to occupation safety and health', 'provisions relating to mortgage', 'provisions relating to occupation safety and health']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.39
#
# 43. Discuss the rules governing gifts and their validity under the Civil Code.
#    Relevant: ['provisions relating to partition', 'provisions relating to mortgage']
#    Retrieved: ['general principles of sentencing', 'public service commission', 'provisions relating to contracts of lease', 'preliminary', 'provisions relating to succession']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 44. Explain the rights and liabilities of partners under the Civil Code.
#    Relevant: ['provisions relating to partnership', 'provisions relating to performance of contracts']
#    Retrieved: ['general principles of sentencing', 'public service commission', 'provisions relating to contracts of lease', 'preliminary', 'federal legislature']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 45. Describe the procedure and grounds for dissolution of partnership under the Civil Code.
#    Relevant: ['family law']
#    Retrieved: ['general principles of sentencing', 'preliminary', 'family law', 'public service commission', 'provisions relating to contracts of lease']
#    → Precision=0.20, Recall=1.00, Hit=1.0, MRR=0.33, NDCG=0.50
#
# 46. Define tortious liability and explain its scope under the Civil Code.
#    Relevant: ['provisions relating to torts', 'provisions relating to mortgage']
#    Retrieved: ['provisions relating to mortgage', 'general principles of sentencing', 'public service commission', 'assessment of net profit from property and liability', 'provisions relating to contracts of lease']
#    → Precision=0.20, Recall=0.50, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 47. Explain the concept of negligence under the law of torts in the Civil Code.
#    Relevant: ['provisions relating to torts', 'preliminary', 'provisions relating to mortgage']
#    Retrieved: ['general principles of sentencing', 'public service commission', 'provisions relating to contracts of lease', 'preliminary', 'preliminary']
#    → Precision=0.40, Recall=0.67, Hit=1.0, MRR=0.25, NDCG=0.20
#
# 48. Discuss the provisions relating to succession and inheritance under the Civil Code.
#    Relevant: ['provisions relating to succession']
#    Retrieved: ['general principles of sentencing', 'provisions relating to occupation safety and health', 'provisions relating to succession', 'public service commission', 'provisions relating to succession']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=0.33, NDCG=0.50
#
# 49. Explain the provisions regarding testamentary succession and wills under the Civil Code.
#    Relevant: ['provisions relating to will', 'provisions relating to succession']
#    Retrieved: ['general principles of sentencing', 'provisions relating to succession', 'provisions relating to succession', 'preliminary', 'provisions relating to succession']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.39
#
# 50. Explain the rights of a coparcener under the Civil Code.
#    Relevant: ['family law']
#    Retrieved: ['general principles of sentencing', '11 articles:', 'public service commission', '11 articles:', 'provisions relating to partition']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 51. Describe the provisions relating to adoption under the Civil Code.
#    Relevant: ['family law', 'provisions relating to adoption']
#    Retrieved: ['general principles of sentencing', 'provisions relating to occupation safety and health', 'provisions relating to inter-country adoption', 'public service commission', 'provisions relating to occupation safety and health']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 52. Explain the grounds and procedure for divorce under the Civil Code.
#    Relevant: ['family law']
#    Retrieved: ['general principles of sentencing', 'preliminary', 'family law', 'public service commission', 'provisions relating to contracts of lease']
#    → Precision=0.20, Recall=1.00, Hit=1.0, MRR=0.33, NDCG=0.50
#
# 53. Discuss the provisions regarding maintenance of spouse and children under the Civil Code.
#    Relevant: ['family law']
#    Retrieved: ['provisions relating to inter-country adoption', 'provisions relating to inter-country adoption', 'general principles of sentencing', 'family law', 'preliminary']
#    → Precision=0.20, Recall=1.00, Hit=1.0, MRR=0.25, NDCG=0.43
#
# 54. Explain the provisions relating to guardianship of minors under the Civil Code.
#    Relevant: ['family law']
#    Retrieved: ['provisions relating to inter-country adoption', 'provisions relating to inter-country adoption', 'general principles of sentencing', 'provisions relating to occupation safety and health', 'public service commission']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 55. Describe the legal requirements for a valid lease agreement under the Civil Code.
#    Relevant: ['provisions relating to contracts of lease']
#    Retrieved: ['general principles of sentencing', 'quantification, allocation and characterization of amounts', 'settlement of collective disputes', 'public service commission', 'provisions relating to contracts of lease']
#    → Precision=0.20, Recall=1.00, Hit=1.0, MRR=0.20, NDCG=0.39
#
# 56. Explain the limitation period for filing civil suits under the Civil Code.
#    Relevant: ['provisions relating to limitation', 'provisions relating to mortgage', 'provisions relating to transactions']
#    Retrieved: ['public service commission', 'provisions relating to contracts of lease', 'public service commission', 'public service commission', 'preliminary']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 57. Explain the doctrine of unjust enrichment under the Civil Code.
#    Relevant: ['provisions relating to unjust enrichment']
#    Retrieved: ['provisions relating to unjust enrichment', 'provisions relating to mortgage', 'provisions relating to unjust enrichment', 'provisions relating to unjust enrichment', 'general principles of sentencing']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 58. Discuss the provisions relating to agency and liability under the Civil Code.
#    Relevant: ['provisions relating to contracts agency', 'provisions relating to government, public and community properties']
#    Retrieved: ['general principles of sentencing', 'provisions relating to occupation safety and health', 'public service commission', 'provisions relating to occupation safety and health', 'preliminary']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 59. Explain the process and requirements for obtaining a license to operate a bank or financial institution under BAFIA 2073.
#    Relevant: ['provisions on license', 'general provisions']
#    Retrieved: ['preliminary', 'provisions on license', 'provisions on license', 'provisions on license', 'provisions on license']
#    → Precision=0.80, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.39
#
# 60. Discuss the provisions relating to merger, acquisition, and amalgamation of banks and financial institutions.
#    Relevant: ['provisions on merger and acquisition of bank or financial institutions']
#    Retrieved: ['provisions on merger and acquisition of bank or financial institutions', 'provisions on merger and acquisition of bank or financial institutions', 'provisions on merger and acquisition of bank or financial institutions', 'assessment of net profit from property and liability', 'preamble']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 61. What are the legal provisions regarding capital adequacy and reserve requirements under BAFIA 2073?
#    Relevant: ['provisions on merger and acquisition of bank or financial institutions', 'provisions on capital, capital fund and liquid assets']
#    Retrieved: ['provisions relating to employment', 'preliminary', 'provisions on capital, capital fund and liquid assets', 'provisions relating to remuneration', 'provisions relating to employment']
#    → Precision=0.20, Recall=0.50, Hit=1.0, MRR=0.33, NDCG=0.31
#
# 62. Describe the roles and powers of the Nepal Rastra Bank in regulating and supervising banks and financial institutions.
#    Relevant: ['miscellaneous', 'provisions on actions, offences and punishment']
#    Retrieved: ['provisions on merger and acquisition of bank or financial institutions', 'provisions on merger and acquisition of bank or financial institutions', 'provisions on license', 'provisions on operation of banking and financial transactions', 'provisions on operation of banking and financial transactions']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 63. Explain the procedures for voluntary and compulsory liquidation of a bank or financial institution under the Act.
#    Relevant: ['provisions on mandatory liquidation of bank or financial institutions', 'mandatory liquidation']
#    Retrieved: ['voluntary liquidation of banks or financial institutions', 'voluntary liquidation of banks or financial institutions', 'voluntary liquidation of banks or financial institutions', 'preliminary', 'voluntary liquidation of banks or financial institutions']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 64. Define banking offence under the Banking Offence and Punishment Act, 2064, and explain its main objectives.
#    Relevant: ['preliminary', 'provisions on actions, offences and punishment']
#    Retrieved: ['preliminary', 'general provisions', 'general provisions', 'general provisions', 'general provisions']
#    → Precision=0.20, Recall=0.50, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 65. Discuss the provisions and penalties relating to cheque fraud and misuse of credit instruments.
#    Relevant: ['banking offences', 'offences relating to documents']
#    Retrieved: ['provisions relating to trusts', 'provisions relating to occupation safety and health', 'banking offences', 'family law', 'banking offences']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=0.33, NDCG=0.31
#
# 66. Explain the legal consequences of unauthorized withdrawal, fund transfer, or embezzlement in banking transactions.
#    Relevant: ['banking offences', 'miscellaneous']
#    Retrieved: ['preamble', 'banking offences', 'provisions on actions, offences and punishment', 'offences against individual privacy and prestige offences against privacy', 'provisions relating to succession']
#    → Precision=0.20, Recall=0.50, Hit=1.0, MRR=0.50, NDCG=0.39
#
# 67. What are the powers of investigation and prosecution authorities under the Banking Offence and Punishment Act?
#    Relevant: ['miscellaneous', 'preamble']
#    Retrieved: ['offences against public justice', 'preliminary', 'general provisions', 'general provisions', 'criminal offences']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 68. Explain the procedures for adjudication and appeal in cases of banking offences.
#    Relevant: ['mandatory liquidation', 'provisions on actions, offences and punishment']
#    Retrieved: ['provisions relating to complaint, punishment and appeal', 'offense and punishment', 'fees and interest', 'preamble', 'provisions relating to complaint, punishment and appeal']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 69. Explain the legal validity of electronic records and digital signatures under the Electronic Commerce Act, 2081.
#    Relevant: ['operation of electronic commerce', 'liablity of parties involved in electronic commerce']
#    Retrieved: ['preliminary', 'preliminary', 'operation of electronic commerce', 'offences and punishment', 'operation of electronic commerce']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=0.33, NDCG=0.31
#
# 70. Discuss the provisions relating to cyber fraud, identity theft, and penalties for offences committed through e-commerce platforms.
#    Relevant: ['operation of electronic commerce', 'liablity of parties involved in electronic commerce']
#    Retrieved: ['offences relating to documents', 'directive principles, policies and obligations of the state', 'offences relating to theft and robbery', 'provisions relating to occupation safety and health', 'offences relating to theft and robbery']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 71. Describe the duties and liabilities of service providers and intermediaries under the Act.
#    Relevant: ['liablity of parties involved in electronic commerce']
#    Retrieved: ['public service commission', 'provisions relating to imprisonment', 'provisions relating to trusts', 'miscellaneous', 'assessment of net profit from property and liability']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 72. Explain the process of authentication and certification of digital documents under the Electronic Commerce Act.
#    Relevant: ['operation of electronic commerce', 'preliminary']
#    Retrieved: ['preliminary', 'offences and punishment', 'operation of electronic commerce', 'preliminary', 'operation of electronic commerce']
#    → Precision=0.80, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.92
#
# 73. Discuss the legal framework governing consumer protection in online transactions.
#    Relevant: ['liablity of parties involved in electronic commerce', 'operation of electronic commerce']
#    Retrieved: ['liablity of parties involved in electronic commerce', 'miscellaneous', 'miscellaneous', 'law relating to persons', 'law relating to persons']
#    → Precision=0.20, Recall=0.50, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 74. Explain the objectives and scope of the International Financial Transactions Act, 2054.
#    Relevant: ['general provisions']
#    Retrieved: ['general provisions', 'general provisions', 'general provisions', 'general provisions', 'general provisions']
#    → Precision=1.00, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 75. Discuss the provisions regarding the regulation and approval of foreign exchange transactions in Nepal.
#    Relevant: ["general provisions'", 'provisions on license']
#    Retrieved: ['unknown', 'provisions on accounts, records, details and reporting', 'provisions concerning transactions of securities', 'provisions on capital, capital fund and liquid assets', 'provisions on capital, capital fund and liquid assets']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 76. Describe the reporting requirements for individuals and institutions engaging in international financial transactions.
#    Relevant: ['general provisions']
#    Retrieved: ['general provisions', 'general provisions', 'general provisions', 'general provisions', 'general provisions']
#    → Precision=1.00, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 77. Explain the penalties for violation of foreign exchange control regulations under the Act.
#    Relevant: ['offences relating to currency', 'provisions on actions, offences and punishment']
#    Retrieved: ['miscellaneous', 'judiciary', 'judiciary', 'offences relating to currency', 'provisions on capital, capital fund and liquid assets']
#    → Precision=0.20, Recall=0.50, Hit=1.0, MRR=0.25, NDCG=0.26
#
# 78. Discuss the powers of the Nepal Rastra Bank in monitoring and enforcing compliance with international financial transaction laws.
#    Relevant: ['miscellaneous', 'provisions on merger and acquisition of bank or financial institutions']
#    Retrieved: ['provisions on merger and acquisition of bank or financial institutions', 'general provisions', 'general provisions', 'general provisions', 'provisions on incorporation of bank or financial institution']
#    → Precision=0.20, Recall=0.50, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 79. Explain the concept of “resident person” and “non-resident person” under the Income Tax Act, 2058.
#    Relevant: ['international tax', 'preliminary']
#    Retrieved: ['preliminary', 'withholding on payment', 'international tax', 'international tax', 'deductible amounts']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.92
#
# 80. Discuss the rules regarding taxable income, exempt income, and deductions allowed under the Act.
#    Relevant: ['income return and assessment of tax', 'exemptible amounts and other exemptions']
#    Retrieved: ['international tax', 'income return and assessment of tax', 'exemptible amounts and other exemptions', 'tax bases', 'tax bases']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.69
#
# 81. Explain the provisions for taxation of business income and capital gains under the Income Tax Act.
#    Relevant: ['income return and assessment of tax', 'preliminary']
#    Retrieved: ['income return and assessment of tax', 'deductible amounts', 'tax bases', 'installment and advance tax', 'special provisions on banking and insurance business']
#    → Precision=0.20, Recall=0.50, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 82. Describe the process of tax assessment, payment, and appeal under the Act.
#    Relevant: ['income return and assessment of tax', 'preliminary']
#    Retrieved: ['preliminary', 'income return and assessment of tax', 'income return and assessment of tax', 'provisions relating to complaint, punishment and appeal', 'fees and interest']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 83. Discuss the provisions relating to advance tax, withholding tax, and penalties for tax evasion.
#    Relevant: ['withholding on payment', 'collection, remission and refund of tax']
#    Retrieved: ['withholding on payment', 'withholding on payment', 'withholding on payment', 'withholding on payment', 'withholding on payment']
#    → Precision=1.00, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.61
#
# ✅ Evaluation Summary (Average):
# {
#   "precision": 0.33253012048192776,
#   "recall": 0.6465863453815262,
#   "hit_rate": 0.7349397590361446,
#   "mrr": 0.4867469879518072,
#   "ndcg": 0.43645890157107897
# }
#
# ===================================================================
#
#
# 1. What are the grounds for disqualification of members of Parliament under the Constitution?
#    Relevant: ['federal legislature', 'judiciary']
#    Retrieved: ['judiciary', 'president and vice-president', 'federal legislature', 'federal legislature', 'judiciary']
#    → Precision=0.80, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.92
#
# 2. Explain the constitutional provisions regarding the right to equality and non-discrimination. What are the permitted classifications?
#    Relevant: ['fundamental rights and duties', 'preliminary']
#    Retrieved: ['financial provisions', 'directive principles, policies and obligations of the state', 'directive principles, policies and obligations of the state', 'provisions relating to inter-country adoption', 'provisions relating to hire-purchase contracts (inferred)']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 3. Describe the procedure for declaring a state of emergency under the Constitution of Nepal.
#    Relevant: ['emergency power', 'provisions relating to national security']
#    Retrieved: ['state executive', 'emergency power', 'president and vice-president', 'emergency power', 'state legislature']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.39
#
# 4. What constitutional remedies are available for the enforcement of fundamental rights in Nepal?
#    Relevant: ['amendment to the constitution', 'judiciary']
#    Retrieved: ['fundamental rights and duties', 'judiciary', 'judiciary', 'national human rights commission', 'emergency power']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.39
#
# 5. What provisions exist to safeguard minorities and marginalized groups in the Constitution of Nepal?
#    Relevant: ['fundamental rights and duties', 'preliminary']
#    Retrieved: ['definitions and interpretations', 'other commissions', 'transitional provisions', 'provisions relating to occupation safety and health', 'fundamental rights and duties']
#    → Precision=0.20, Recall=0.50, Hit=1.0, MRR=0.20, NDCG=0.24
#
# 6. Explain the principle of separation of powers under the Constitution of Nepal.
#    Relevant: ['structure of state and distribution of state power', 'judiciary']
#    Retrieved: ['structure of state and distribution of state power', 'president and vice-president', 'transitional provisions', 'preliminary', 'federal executive']
#    → Precision=0.20, Recall=0.50, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 7. Discuss the composition and jurisdiction of constitutional councils and commissions in Nepal.
#    Relevant: ['miscellaneous', 'transitional provisions']
#    Retrieved: ['interrelations between federation, state and local level', 'structure of state and distribution of state power', 'miscellaneous', 'attorney general', 'miscellaneous']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=0.33, NDCG=0.31
#
# 8. Explain the financial powers of Parliament and the procedure for budget formulation in Nepal.
#    Relevant: ['financial provisions', 'structure of state and distribution of state power']
#    Retrieved: ['general provisions', 'provisions on board of directors and chief executive', 'public service commission', 'federal legislative procedures', 'structure of state and distribution of state power']
#    → Precision=0.20, Recall=0.50, Hit=1.0, MRR=0.20, NDCG=0.24
#
# 9. Describe the federal structure and distribution of powers between the federation and provinces.
#    Relevant: ['structure of state and distribution of state power']
#    Retrieved: ['structure of state and distribution of state power', 'judiciary', 'national natural resources and fiscal commission', 'structure of state and distribution of state power', 'state executive']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 10. Explain the constitutional right to privacy guaranteed under the Constitution of Nepal.
#    Relevant: ['fundamental rights and duties', 'preliminary']
#    Retrieved: ['transitional provisions', 'preliminary', 'preliminary', 'transitional provisions', 'president and vice-president']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.39
#
# 11. Define the offence of cheating under the Muluki Penal Code.
#    Relevant: ['offences relating to cheating, criminal breach of trust and extortion']
#    Retrieved: ['general principles of sentencing', 'miscellaneous', 'offences relating to cheating, criminal breach of trust and extortion', 'offences relating to cheating, criminal breach of trust and extortion', 'general provisions']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=0.33, NDCG=0.50
#
# 12. Distinguish between private defense of body and property under the Penal Code.
#    Relevant: ['general provisions']
#    Retrieved: ['general principles of sentencing', 'general provisions', 'miscellaneous', 'general provisions', 'provisions relating to private international law']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.63
#
# 13. Explain the degrees and principles of punishment under the Penal Code.
#    Relevant: ['general principles of sentencing']
#    Retrieved: ['general principles of sentencing', 'miscellaneous', 'directive principles, policies and obligations of the state', 'general provisions', 'provisions on disbursement and recovery of credits']
#    → Precision=0.20, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 14. Discuss the concept of abetment and its punishment under the Penal Code.
#    Relevant: ['general provisions']
#    Retrieved: ['general principles of sentencing', 'miscellaneous', 'national human rights commission', 'provisions on disbursement and recovery of credits', 'preamble']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 15. Differentiate between criminal breach of trust and theft under the Penal Code.
#    Relevant: ['offences relating to cheating, criminal breach of trust and extortion', 'provisions relating to trusts']
#    Retrieved: ['general principles of sentencing', 'provisions relating to trusts', 'general provisions', 'provisions relating to trusts', 'provisions relating to trusts']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.39
#
# 16. Explain the offences of wrongful confinement and kidnapping under the Penal Code.
#    Relevant: ['offences relating to kidnapping or taking of hostages']
#    Retrieved: ['general principles of sentencing', 'miscellaneous', 'offences relating to theft and robbery', 'offences relating to explosives', 'offences against national and public heritages']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 17. Discuss offences against public tranquility under the Penal Code.
#    Relevant: ['offences against public tranquility', 'offences against public interest, health, safety, convenience and morals', "'criminal offences'"]
#    Retrieved: ['general principles of sentencing', 'miscellaneous', 'criminal offences', 'general provisions', 'offences relating to explosives']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 18. Define ‘voluntarily causing hurt’ and ‘grievous hurt’ under the Penal Code.
#    Relevant: ['offences relating to hurt or grievous hurt', 'offence relating to medical treatment']
#    Retrieved: ['general principles of sentencing', 'miscellaneous', 'provisions on disbursement and recovery of credits', 'provisions on disbursement and recovery of credits', 'preliminary']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 19. Explain the offence of defamation and its defenses under the Penal Code.
#    Relevant: ['offence relating to defamation', 'fundamental rights and duties']
#    Retrieved: ['general principles of sentencing', 'miscellaneous', 'provisions on disbursement and recovery of credits', 'offences relating to theft and robbery', 'offences relating to contempt of authority of public servants']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 20. Discuss the offences of forgery and counterfeiting under the Penal Code.
#    Relevant: ['offences relating to documents', 'offences relating to currency']
#    Retrieved: ['general principles of sentencing', 'offences relating to documents', 'miscellaneous', 'offences relating to theft and robbery', 'offences relating to explosives']
#    → Precision=0.20, Recall=0.50, Hit=1.0, MRR=0.50, NDCG=0.39
#
# 21. Explain the doctrine of transferred malice under the Penal Code.
#    Relevant: ['preliminary', 'general principles of sentencing']
#    Retrieved: ['general principles of sentencing', 'miscellaneous', 'general provisions', 'provisions relating to trusts', 'provisions relating to internal management of enterprise']
#    → Precision=0.20, Recall=0.50, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 22. Discuss the provisions relating to sexual offences and punishment under the Penal Code.
#    Relevant: ['sexual offences']
#    Retrieved: ['general principles of sentencing', 'general provisions', 'provisions relating to occupation safety and health', 'provisions relating to conduct and punishment', 'provisions relating to occupation safety and health']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 23. Explain the provisions for minimum wage under the Labour Act.
#    Relevant: ['basic provisions relating to labours', 'miscellaneous']
#    Retrieved: ['miscellaneous', 'provisions relating to council and committee', 'provisions relating to industry or service of special nature', 'miscellaneous', 'provisions relating to supply of labours']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 24. Describe the rules regarding maternity leave and benefits under the Labour Act.
#    Relevant: ['provisions relating to leave']
#    Retrieved: ['provisions relating to supply of labours', 'provisions relating to remuneration', 'provisions relating to leave', 'provisions relating to work permit', 'preliminary']
#    → Precision=0.20, Recall=1.00, Hit=1.0, MRR=0.33, NDCG=0.50
#
# 25. What constitutes unfair labour practice under the Labour Act?
#    Relevant: ['provisions relating to fair labour practice', 'basic provisions relating to labours']
#    Retrieved: ['provisions relating to fair labour practice', 'provisions relating to fair labour practice', 'provisions relating to fair labour practice', 'provisions relating to complaint, punishment and appeal', 'provisions relating to fair labour practice']
#    → Precision=0.80, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 26. Explain the legal provisions relating to child labour under the Labour Act.
#    Relevant: ['basic provisions relating to labours', 'fundamental rights and duties']
#    Retrieved: ['preamble', 'provisions relating to employment', 'provisions relating to supply of labours', 'settlement of collective disputes', 'provisions relating to termination of employment']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 27. Describe the procedure for registration of trade unions under the Labour Act.
#    Relevant: ['basic provisions relating to labours', 'preliminary']
#    Retrieved: ['provisions relating to council and committee', 'provisions relating to council and committee', 'settlement of collective disputes', 'miscellaneous', 'provisions relating to industry or service of special nature']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 28. Explain the process and importance of collective bargaining under the Labour Act.
#    Relevant: ['settlement of collective disputes', 'preliminary']
#    Retrieved: ['preliminary', 'settlement of collective disputes', 'settlement of collective disputes', 'settlement of collective disputes', 'settlement of collective disputes']
#    → Precision=1.00, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 29. Discuss the grounds and procedures for termination of employment under the Labour Act.
#    Relevant: ['provisions relating to termination of employment']
#    Retrieved: ['miscellaneous', 'provisions relating to work permit', 'provisions relating to termination of employment', 'provisions relating to termination of employment', 'provisions relating to termination of employment']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=0.33, NDCG=0.50
#
# 30. Explain the provisions regarding social security and welfare funds under the Labour Act.
#    Relevant: ['provisions relating to provident fund, gratuity and insurance', "'provisions relating to remuneration'"]
#    Retrieved: ['provisions relating to provident fund, gratuity and insurance', 'provisions relating to termination of employment', 'preliminary', 'fundamental rights and duties', 'provisions relating to supply of labours']
#    → Precision=0.20, Recall=0.50, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 31. Describe the provisions regarding provident fund and gratuity under the Labour Act.
#    Relevant: ['provisions relating to provident fund, gratuity and insurance']
# ...
#    → Precision=0.20, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.63
#
# 46. Define tortious liability and explain its scope under the Civil Code.
#    Relevant: ['provisions relating to torts', 'provisions relating to mortgage']
#    Retrieved: ['provisions relating to torts', 'provisions relating to torts', 'provisions relating to torts', 'provisions relating to torts', 'preliminary']
#    → Precision=0.80, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 47. Explain the concept of negligence under the law of torts in the Civil Code.
#    Relevant: ['provisions relating to torts', 'preliminary', 'provisions relating to mortgage']
#    Retrieved: ['provisions relating to torts', 'provisions relating to torts', 'provisions relating to government, public and community properties', 'provisions relating to torts', 'offences relating to human body']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.47
#
# 48. Discuss the provisions relating to succession and inheritance under the Civil Code.
#    Relevant: ['provisions relating to succession']
#    Retrieved: ['provisions relating to succession', 'provisions relating to succession', 'provisions relating to succession', 'provisions relating to succession', 'preliminary']
#    → Precision=0.80, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 49. Explain the provisions regarding testamentary succession and wills under the Civil Code.
#    Relevant: ['provisions relating to will', 'provisions relating to succession']
#    Retrieved: ['provisions relating to succession', 'provisions relating to succession', 'provisions relating to succession', 'provisions relating to succession', 'provisions relating to succession']
#    → Precision=1.00, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 50. Explain the rights of a coparcener under the Civil Code.
#    Relevant: ['family law']
#    Retrieved: ['provisions relating to partition', '', 'provisions relating to partition', '', '']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 51. Describe the provisions relating to adoption under the Civil Code.
#    Relevant: ['family law', 'provisions relating to adoption']
#    Retrieved: ['provisions relating to adoption', 'provisions relating to mortgage', 'provisions relating to adoption', 'provisions relating to adoption', 'provisions relating to adoption']
#    → Precision=0.80, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 52. Explain the grounds and procedure for divorce under the Civil Code.
#    Relevant: ['family law']
#    Retrieved: ['family law', 'family law', 'family law', 'family law', 'family law']
#    → Precision=1.00, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 53. Discuss the provisions regarding maintenance of spouse and children under the Civil Code.
#    Relevant: ['family law']
#    Retrieved: ['family law', 'family law', 'family law', 'family law', 'family law']
#    → Precision=1.00, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 54. Explain the provisions relating to guardianship of minors under the Civil Code.
#    Relevant: ['family law']
#    Retrieved: ['family law', 'family law', 'family law', 'family law', 'provisions relating to torts']
#    → Precision=0.80, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 55. Describe the legal requirements for a valid lease agreement under the Civil Code.
#    Relevant: ['provisions relating to contracts of lease']
#    Retrieved: ['provisions relating to inter-country adoption', 'provisions relating to contracts of lease', 'provisions relating to contracts of lease', 'provisions relating to contracts of lease', 'provisions relating to contracts of lease']
#    → Precision=0.80, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.63
#
# 56. Explain the limitation period for filing civil suits under the Civil Code.
#    Relevant: ['provisions relating to limitation', 'provisions relating to mortgage', 'provisions relating to transactions']
#    Retrieved: ['provisions relating to transactions', 'provisions relating to transactions', 'provisions relating to mortgage', 'provisions relating to succession', 'provisions relating to partition']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.70
#
# 57. Explain the doctrine of unjust enrichment under the Civil Code.
#    Relevant: ['provisions relating to unjust enrichment']
#    Retrieved: ['provisions relating to unjust enrichment', 'provisions relating to unjust enrichment', 'provisions relating to unjust enrichment', 'provisions relating to unjust enrichment', 'provisions relating to unjust enrichment']
#    → Precision=1.00, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 58. Discuss the provisions relating to agency and liability under the Civil Code.
#    Relevant: ['provisions relating to contracts agency', 'provisions relating to government, public and community properties']
#    Retrieved: ['provisions relating to contracts of agency', 'provisions relating to contracts of agency', 'provisions relating to contracts of agency', 'provisions relating to contracts of agency', 'provisions relating to contracts of agency']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 59. Explain the process and requirements for obtaining a license to operate a bank or financial institution under BAFIA 2073.
#    Relevant: ['provisions on license', 'general provisions']
#    Retrieved: ['preliminary', 'provisions on actions, offences and punishment', 'provisions on license', 'provisions on incorporation of bank or financial institution', 'provisions on license']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=0.33, NDCG=0.31
#
# 60. Discuss the provisions relating to merger, acquisition, and amalgamation of banks and financial institutions.
#    Relevant: ['provisions on merger and acquisition of bank or financial institutions']
#    Retrieved: ['provisions on merger and acquisition of bank or financial institutions', 'preliminary', 'provisions on merger and acquisition of bank or financial institutions', 'mandatory liquidation', 'provisions on merger and acquisition of bank or financial institutions']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 61. What are the legal provisions regarding capital adequacy and reserve requirements under BAFIA 2073?
#    Relevant: ['provisions on merger and acquisition of bank or financial institutions', 'provisions on capital, capital fund and liquid assets']
#    Retrieved: ['preliminary', 'provisions on capital, capital fund and liquid assets', 'provisions on capital, capital fund and liquid assets', 'provisions on license', 'provisions on merger and acquisition of bank or financial institutions']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.62
#
# 62. Describe the roles and powers of the Nepal Rastra Bank in regulating and supervising banks and financial institutions.
#    Relevant: ['miscellaneous', 'provisions on actions, offences and punishment']
#    Retrieved: ['provisions on incorporation of bank or financial institution', 'provisions on board of directors and chief executive', 'provisions on actions, offences and punishment', 'general provisions', 'provisions on incorporation of bank or financial institution']
#    → Precision=0.20, Recall=0.50, Hit=1.0, MRR=0.33, NDCG=0.31
#
# 63. Explain the procedures for voluntary and compulsory liquidation of a bank or financial institution under the Act.
#    Relevant: ['provisions on mandatory liquidation of bank or financial institutions', 'mandatory liquidation']
#    Retrieved: ['voluntary liquidation of banks or financial institutions', 'provisions on mandatory liquidation of bank or financial institutions', 'mandatory liquidation', 'provisions on actions, offences and punishment', 'voluntary liquidation of banks or financial institutions']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.69
#
# 64. Define banking offence under the Banking Offence and Punishment Act, 2064, and explain its main objectives.
#    Relevant: ['preliminary', 'provisions on actions, offences and punishment']
#    Retrieved: ['preliminary', '', 'preliminary', 'provisions on incorporation of bank or financial institution', 'punishment']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 65. Discuss the provisions and penalties relating to cheque fraud and misuse of credit instruments.
#    Relevant: ['banking offences', 'offences relating to documents']
#    Retrieved: ['banking offences', 'banking offences', 'banking offences', 'banking offences', 'banking offences']
#    → Precision=1.00, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 66. Explain the legal consequences of unauthorized withdrawal, fund transfer, or embezzlement in banking transactions.
#    Relevant: ['banking offences', 'miscellaneous']
#    Retrieved: ['banking offences', 'banking offences', 'mandatory liquidation', 'banking offences', 'provisions on actions, offences and punishment']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 67. What are the powers of investigation and prosecution authorities under the Banking Offence and Punishment Act?
#    Relevant: ['miscellaneous', 'preamble']
#    Retrieved: ['miscellaneous', 'mandatory liquidation', 'miscellaneous', '', 'miscellaneous']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 68. Explain the procedures for adjudication and appeal in cases of banking offences.
#    Relevant: ['mandatory liquidation', 'provisions on actions, offences and punishment']
#    Retrieved: ['provisions on actions, offences and punishment', 'provisions on incorporation of bank or financial institution', 'miscellaneous', 'preliminary', 'provisions on actions, offences and punishment']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.61
#
# 69. Explain the legal validity of electronic records and digital signatures under the Electronic Commerce Act, 2081.
#    Relevant: ['operation of electronic commerce', 'liablity of parties involved in electronic commerce']
#    Retrieved: ['operation of electronic commerce', 'preliminary', 'operation of electronic commerce', 'preliminary', 'liablity of parties involved in electronic commerce']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.85
#
# 70. Discuss the provisions relating to cyber fraud, identity theft, and penalties for offences committed through e-commerce platforms.
#    Relevant: ['operation of electronic commerce', 'liablity of parties involved in electronic commerce']
#    Retrieved: ['preliminary', 'preliminary', 'liablity of parties involved in electronic commerce', 'operation of electronic commerce', 'operation of electronic commerce']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=0.33, NDCG=0.57
#
# 71. Describe the duties and liabilities of service providers and intermediaries under the Act.
#    Relevant: ['liablity of parties involved in electronic commerce']
#    Retrieved: ['liablity of parties involved in electronic commerce', 'collection, remission and refund of tax', 'preliminary', 'provisions relating to contracts of agency', 'liablity of parties involved in electronic commerce']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 72. Explain the process of authentication and certification of digital documents under the Electronic Commerce Act.
#    Relevant: ['operation of electronic commerce', 'preliminary']
#    Retrieved: ['tax administration and authentic documents', 'operation of electronic commerce', 'operation of electronic commerce', 'preliminary', 'miscellaneous']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.65
#
# 73. Discuss the legal framework governing consumer protection in online transactions.
#    Relevant: ['liablity of parties involved in electronic commerce', 'operation of electronic commerce']
#    Retrieved: ['miscellaneous', 'liablity of parties involved in electronic commerce', 'operation of electronic commerce', 'liablity of parties involved in electronic commerce', 'preliminary']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=0.50, NDCG=0.69
#
# 74. Explain the objectives and scope of the International Financial Transactions Act, 2054.
#    Relevant: ['general provisions']
#    Retrieved: ['general provisions', 'general provisions', 'general provisions', 'general provisions', 'general provisions']
#    → Precision=1.00, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 75. Discuss the provisions regarding the regulation and approval of foreign exchange transactions in Nepal.
#    Relevant: ["general provisions'", 'provisions on license']
#    Retrieved: ['general provisions', '', 'general provisions', 'provisions relating to mortgage', 'general provisions']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 76. Describe the reporting requirements for individuals and institutions engaging in international financial transactions.
#    Relevant: ['general provisions']
#    Retrieved: ['general provisions', 'general provisions', 'general provisions', 'general provisions', 'general provisions']
#    → Precision=1.00, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 77. Explain the penalties for violation of foreign exchange control regulations under the Act.
#    Relevant: ['offences relating to currency', 'provisions on actions, offences and punishment']
#    Retrieved: ['offences relating to currency', 'provisions on actions, offences and punishment', 'offense and punishment', 'offences relating to currency', 'general provisions']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=1.00
#
# 78. Discuss the powers of the Nepal Rastra Bank in monitoring and enforcing compliance with international financial transaction laws.
#    Relevant: ['miscellaneous', 'provisions on merger and acquisition of bank or financial institutions']
#    Retrieved: ['general provisions', 'provisions on incorporation of bank or financial institution', '', 'general provisions', 'general provisions']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 79. Explain the concept of “resident person” and “non-resident person” under the Income Tax Act, 2058.
#    Relevant: ['international tax', 'preliminary']
#    Retrieved: ['preliminary', 'preliminary', 'international tax', 'general provisions', 'tax bases']
#    → Precision=0.60, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.92
#
# 80. Discuss the rules regarding taxable income, exempt income, and deductions allowed under the Act.
#    Relevant: ['income return and assessment of tax', 'exemptible amounts and other exemptions']
#    Retrieved: ['special provisions on retirement saving', 'assessment of net profit from property and liability', 'income return and assessment of tax', 'preliminary', 'special provisions on banking and insurance business']
#    → Precision=0.20, Recall=0.50, Hit=1.0, MRR=0.33, NDCG=0.31
#
# 81. Explain the provisions for taxation of business income and capital gains under the Income Tax Act.
#    Relevant: ['income return and assessment of tax', 'preliminary']
#    Retrieved: ['computation of tax', 'tax bases', 'deductible amounts', 'computation of tax', 'deductible amounts']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# 82. Describe the process of tax assessment, payment, and appeal under the Act.
#    Relevant: ['income return and assessment of tax', 'preliminary']
#    Retrieved: ['preliminary', 'review and appeal', '', 'income return and assessment of tax', 'payment of tax']
#    → Precision=0.40, Recall=1.00, Hit=1.0, MRR=1.00, NDCG=0.88
#
# 83. Discuss the provisions relating to advance tax, withholding tax, and penalties for tax evasion.
#    Relevant: ['withholding on payment', 'collection, remission and refund of tax']
#    Retrieved: ['preliminary', 'installment and advance tax', 'payment of tax', 'installment and advance tax', 'installment and advance tax']
#    → Precision=0.00, Recall=0.00, Hit=0.0, MRR=0.00, NDCG=0.00
#
# ✅ Evaluation Summary (Average):
# {
#   "precision": 0.636144578313253,
#   "recall": 0.8875502008032128,
#   "hit_rate": 0.9156626506024096,
#   "mrr": 0.8112449799196787,
#   "ndcg": 0.7206879928785073
# }
#
# ===================================================================

# %%
# ============================================================
# 🔹 Create DataFrame for Visualization
# ============================================================
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Reset matplotlib style to default (removes seaborn styling)
plt.style.use('default')

df = pd.DataFrame(results).T  # transpose to make models as rows
df = df[["precision", "recall", "hit_rate", "mrr", "ndcg"]]  # ensure column order

print("\n📈 Evaluation Summary Table:")
print(df.round(3))

# ============================================================
# 🔹 Plot Bar Chart Comparison
# ============================================================

plt.figure(figsize=(10, 6))
df.plot(kind="bar", figsize=(12, 6), width=0.8)
plt.title("Retriever Performance Comparison")
plt.ylabel("Score")
plt.xlabel("Retriever Models")
plt.ylim(0, 1)
plt.legend(title="Metrics")
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()

# ============================================================
# 🔹 Plot Heatmap for Quick Comparison
# ============================================================

import seaborn as sns

plt.figure(figsize=(10, 6))
sns.heatmap(df, annot=True, fmt='.3f', cmap='RdYlGn', linewidths=0.5, 
            cbar_kws={'label': 'Score'}, vmin=0, vmax=1)

plt.title('Retriever Performance Heatmap', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Metrics', fontsize=12, fontweight='bold')
plt.ylabel('Models', fontsize=12, fontweight='bold')
plt.xticks(rotation=0, fontsize=11)
plt.yticks(rotation=0, fontsize=10)
plt.tight_layout()
plt.show()

# Reset style back to default after heatmap
plt.style.use('default')
# Out:
# 📈 Evaluation Summary Table:
#                                         precision  recall  hit_rate    mrr  \
# TF-IDF                                      0.333   0.647     0.735  0.487
# BM25                                        0.241   0.476     0.578  0.392
# BGE Large + BM25 (Hybrid)                   0.634   0.940     0.964  0.764
# BAAI/bge-base-en-v1.5                       0.590   0.894     0.928  0.798
# BAAI/bge-large-en-v1.5                      0.634   0.940     0.964  0.818
# sentence-transformers/all-MiniLM-L6-v2      0.545   0.865     0.940  0.760
# text-embedding-004                          0.636   0.888     0.916  0.811
#
#                                          ndcg
# TF-IDF                                  0.436
# BM25                                    0.339
# BGE Large + BM25 (Hybrid)               0.770
# BAAI/bge-base-en-v1.5                   0.773
# BAAI/bge-large-en-v1.5                  0.810
# sentence-transformers/all-MiniLM-L6-v2  0.722
# text-embedding-004                      0.721
